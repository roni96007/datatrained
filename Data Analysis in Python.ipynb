# %% [markdown]
# # Data Analysis in Python Using Python

# %%
import pandas as pd
import numpy as np

# %%
df=pd.DataFrame({'Day':[1,2,3,4,5,6,7,8],'visitors':[100,200,300,400,500,600,700,800],'bouncer':[200,400,600,800,1000,1200,1400,1600]})
df
# Out:
#    Day  visitors  bouncer
# 0    1       100      200
# 1    2       200      400
# 2    3       300      600
# 3    4       400      800
# 4    5       500     1000
# 5    6       600     1200
# 6    7       700     1400
# 7    8       800     1600

# %%
df.head()        #by default showing top 5 data
# Out:
#    Day  visitors  bouncer
# 0    1       100      200
# 1    2       200      400
# 2    3       300      600
# 3    4       400      800
# 4    5       500     1000

# %%
df.tail()          #by default showing last 5 data
# Out:
#    Day  visitors  bouncer
# 3    4       400      800
# 4    5       500     1000
# 5    6       600     1200
# 6    7       700     1400
# 7    8       800     1600

# %%
df.head(3)
# Out:
#    Day  visitors  bouncer
# 0    1       100      200
# 1    2       200      400
# 2    3       300      600

# %%
df.tail(4)
# Out:
#    Day  visitors  bouncer
# 4    5       500     1000
# 5    6       600     1200
# 6    7       700     1400
# 7    8       800     1600

# %%
df.sample()   #showing By default random one data
# Out:
#    Day  visitors  bouncer
# 5    6       600     1200

# %%
df.sample(3)   #showing random n number of data
# Out:
#    Day  visitors  bouncer
# 4    5       500     1000
# 6    7       700     1400
# 3    4       400      800

# %%
df.sample(2)
# Out:
#    Day  visitors  bouncer
# 1    2       200      400
# 2    3       300      600

# %% [markdown]
# # INPUT/OUTPUT TOOLS

# %% [markdown]
# USING CSV FILE (COMMA SEPARATED VALUE)

# %%
df=pd.read_csv('Student.csv')     #reading from csv file
df
# Out:
#     Name         DOB   Location  Gender
# 0    Ram  18/06/2000    Kolkata    Male
# 1  Bheem  14/08/1996  Medinipur    Male
# 2   Riya  16/10/1998   Kolaghat  Female
# 3  Priti  22/12/1999    Kolkata  Female
# 4   Jhon  17/02/2000        Usa    Male
# 5   Jack  19/04/1995    England    Male
# 6    Sam  20/05/1999    Newyork  Female

# %%
print(type(df['DOB'][0]))     #checking type of the coloumn
# Out:
# <class 'str'>

# %%
df1=df.set_index('Name')     #changing index method 1
df1
# Out:
#               DOB   Location  Gender
# Name
# Ram    18/06/2000    Kolkata    Male
# Bheem  14/08/1996  Medinipur    Male
# Riya   16/10/1998   Kolaghat  Female
# Priti  22/12/1999    Kolkata  Female
# Jhon   17/02/2000        Usa    Male
# Jack   19/04/1995    England    Male
# Sam    20/05/1999    Newyork  Female

# %%
df2=pd.read_csv('Student.csv',header=0,names=['STUNAME','DOB','BRANCH','GENDER'],index_col='STUNAME')   #change coloumn name using header=0 method
df2
# Out:
#                 DOB     BRANCH  GENDER
# STUNAME
# Ram      18/06/2000    Kolkata    Male
# Bheem    14/08/1996  Medinipur    Male
# Riya     16/10/1998   Kolaghat  Female
# Priti    22/12/1999    Kolkata  Female
# Jhon     17/02/2000        Usa    Male
# Jack     19/04/1995    England    Male
# Sam      20/05/1999    Newyork  Female

# %%
df2
df2.to_csv('updatestudent.csv')       #save existing data to a new updated file

# %%
dfFINAL2=pd.read_csv('updatestudent.csv')      #reading updated csv file
dfFINAL2
# Out:
#   STUNAME         DOB     BRANCH  GENDER
# 0     Ram  18/06/2000    Kolkata    Male
# 1   Bheem  14/08/1996  Medinipur    Male
# 2    Riya  16/10/1998   Kolaghat  Female
# 3   Priti  22/12/1999    Kolkata  Female
# 4    Jhon  17/02/2000        Usa    Male
# 5    Jack  19/04/1995    England    Male
# 6     Sam  20/05/1999    Newyork  Female

# %%
print(type(df1['DOB'][0]))        #checking Type of the date coloumn
# Out:
# <class 'str'>

# %%
df=pd.read_csv('Student.csv',parse_dates=['DOB'])    #changing date data from string to timestamp
df
# Out:
#     Name        DOB   Location  Gender
# 0    Ram 2000-06-18    Kolkata    Male
# 1  Bheem 1996-08-14  Medinipur    Male
# 2   Riya 1998-10-16   Kolaghat  Female
# 3  Priti 1999-12-22    Kolkata  Female
# 4   Jhon 2000-02-17        Usa    Male
# 5   Jack 1995-04-19    England    Male
# 6    Sam 1999-05-20    Newyork  Female

# %%
print(type(df['DOB'][0]))         #checking type after changing date data
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
df1=pd.read_csv('Student.csv',parse_dates=['DOB'])

# %%
print(type(df['DOB'][4]))
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
df2=pd.read_csv('EMPLOYEE.csv')
df2
# Out:
#        Name  Emid  Age       Branch         DOJ
# 0     satis   101   25      kolkata  18/06/2000
# 1     siman   102   21     saltlake  14/08/1996
# 2    sitesh   103   36        garia  22/12/1999
# 3  sremoyee   104   22    berhampur  22/12/1999
# 4      sree   105   31       dumdum  22/12/1999
# 5     soumi   106   27     Beldanga  14/08/1996
# 6     sreji   107   26  murshidabad  18/06/2000
# 7   sikanta   108   28   girishpark  22/12/1999

# %%
df3=df2.set_index('Name')
df3
# Out:
#           Emid  Age       Branch         DOJ
# Name
# satis      101   25      kolkata  18/06/2000
# siman      102   21     saltlake  14/08/1996
# sitesh     103   36        garia  22/12/1999
# sremoyee   104   22    berhampur  22/12/1999
# sree       105   31       dumdum  22/12/1999
# soumi      106   27     Beldanga  14/08/1996
# sreji      107   26  murshidabad  18/06/2000
# sikanta    108   28   girishpark  22/12/1999

# %%
df3['Age'].plot.bar()      #bar plot of age column
# Out:
# <AxesSubplot:xlabel='Name'>

# %%
print(type(df3['DOJ']['satis']))
# Out:
# <class 'str'>

# %%
df2=pd.read_csv('EMPLOYEE.csv',parse_dates=['DOJ'])
df2
# Out:
#        Name  Emid  Age       Branch        DOJ
# 0     satis   101   25      kolkata 2000-06-18
# 1     siman   102   21     saltlake 1996-08-14
# 2    sitesh   103   36        garia 1999-12-22
# 3  sremoyee   104   22    berhampur 1999-12-22
# 4      sree   105   31       dumdum 1999-12-22
# 5     soumi   106   27     Beldanga 1996-08-14
# 6     sreji   107   26  murshidabad 2000-06-18
# 7   sikanta   108   28   girishpark 1999-12-22

# %%
df1=pd.read_csv('course.csv')
df1
# Out:
#      Name   ID       Course         DOJ
# 0   shrey  201  datascience  02/04/2022
# 1     pri  401         java  05/08/2022
# 2    rish  401         java  18/06/2022
# 3    Roni  504      Flutter  16/07/2022
# 4   choto  701       python  18/09/2022
# 5  skdkkc  402         math  05/02/2022
# 6   dsbdb  301      bengali  12/10/2022
# 7    bjhb  504      Flutter  12/12/2022

# %%
print(df1['ID'].plot.bar())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print(type(df1['Course'][2]))
# Out:
# <class 'str'>

# %%
df2=pd.read_csv('Course.csv', index_col='ID', parse_dates=['DOJ'],header=0,names=['StudentName','ID','CourseName','DOJ'])   #set index column using index_col method
df2
# Out:
#     StudentName   CourseName        DOJ
# ID
# 201       shrey  datascience 2022-02-04
# 401         pri         java 2022-05-08
# 401        rish         java 2022-06-18
# 504        Roni      Flutter 2022-07-16
# 701       choto       python 2022-09-18
# 402      skdkkc         math 2022-05-02
# 301       dsbdb      bengali 2022-12-10
# 504        bjhb      Flutter 2022-12-12

# %%
print(type(df2['DOJ'][301]))
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
df2=pd.read_csv('Course.csv',header=0,names=['StudentName','CourseID','CourseName','DOJ'],index_col='CourseID')
df2
# Out:
#          StudentName   CourseName         DOJ
# CourseID
# 201            shrey  datascience  02/04/2022
# 401              pri         java  05/08/2022
# 401             rish         java  18/06/2022
# 504             Roni      Flutter  16/07/2022
# 701            choto       python  18/09/2022
# 402           skdkkc         math  05/02/2022
# 301            dsbdb      bengali  12/10/2022
# 504             bjhb      Flutter  12/12/2022

# %%
df2
df2.to_csv('NewCourse.csv')

# %%
dfinal=pd.read_csv('NewCourse.csv')
dfinal
# Out:
#    CourseID StudentName   CourseName         DOJ
# 0       201       shrey  datascience  02/04/2022
# 1       401         pri         java  05/08/2022
# 2       401        rish         java  18/06/2022
# 3       504        Roni      Flutter  16/07/2022
# 4       701       choto       python  18/09/2022
# 5       402      skdkkc         math  05/02/2022
# 6       301       dsbdb      bengali  12/10/2022
# 7       504        bjhb      Flutter  12/12/2022

# %% [markdown]
# READING TSV(TAB SEPARATED VALUE) FILE FORMAT

# %%
import pandas as pd
import numpy as np

# %%
A=pd.read_csv('E:\Python\employee1.tsv',sep='\t',index_col=['ID'],parse_dates=['DOB'])
A
# Out:
#      NAME        DOB  SALARY
# ID
# 1     Ram 2022-06-25   20000
# 2   Shyam 2022-04-15   22000
# 3   Jhon  1999-04-08   45000
# 4   Priti 2005-12-05   15000
# 5     Don 2008-07-12   21000

# %%
print(type(A['DOB'][2]))
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
A['SALARY'].min()
# Out:
# 15000

# %%
A['SALARY'].max()
# Out:
# 45000

# %%
A['SALARY'].mean()
# Out:
# 24600.0

# %%
A['SALARY'].plot.bar()
# Out:
# <AxesSubplot:xlabel='ID'>

# %%
b=pd.read_csv('E:\Python\marksdata.tsv',sep='\t',index_col=['stuid'],parse_dates=['dob'])
b
# Out:
#       name place        dob  marks
# stuid
# 1      ghj   vhj 2022-10-02     88
# 2      jkl   cgh 2021-11-03     96
# 3      fgh   tyy 2011-04-21     65
# 4      wer   bnm 1999-12-06     84
# 5      cxd   pok 2021-06-04     36

# %%
b['marks'].plot.bar()
# Out:
# <AxesSubplot:xlabel='stuid'>

# %%
b1=pd.read_csv('E:\Python\marksdata.tsv',sep='\t',header=0,names=['stuid','name','branch','dob','marksobt'])
b1
# Out:
#    stuid name branch         dob  marksobt
# 0      1  ghj    vhj  10/02/2022        88
# 1      2  jkl    cgh  11/03/2021        96
# 2      3  fgh    tyy  21/04/2011        65
# 3      4  wer    bnm  12/06/1999        84
# 4      5  cxd    pok  06/04/2021        36

# %%
b1['marksobt'].max()
# Out:
# 96

# %%
b1['marksobt'].min()
# Out:
# 36

# %%
b1['marksobt'].mean()
# Out:
# 73.8

# %%
c=pd.read_csv('employee23.csv',sep=':',index_col=['ID'],parse_dates=['DOB'],header=0,names=['ID','NAMES','DOB','CTC'])
c
# Out:
#          NAMES        DOB    CTC
# ID
# 401       udsy 2007-08-15  55000
# 559    sdgvhbs 1999-05-13  40000
# 125   dsgvshbf 1996-08-09  30225
# 1251   sfbuyfj 2006-12-04  65451

# %%
c.to_csv('newemployee23.csv',sep=';')      #changing file format using separator

# %%
c['CTC'].plot.bar()
# Out:
# <AxesSubplot:xlabel='ID'>

# %%
c['CTC'].min()
# Out:
# 30225

# %% [markdown]
# READING FROM EXCEL FILE

# %%
D=pd.read_excel('E:\Onboarding.xlsx')
D
# Out:
#                      NAME      Mobile               HUB NAME     STATUS  \
# 0             Raja Mondal  7363829439  JagatballavpurHUB_BAC  ONBOARDED
# 1              Bikram Das  6296875698  JagatballavpurHUB_BAC  ONBOARDED
# 2          Sourav Samanta  8420932177        UluberiaHUB_ULB  ONBOARDED
# 3          Raghunath Rong  9547917952        UluberiaHUB_ULB  ONBOARDED
# 4             Susanta Bag  7715956761  JagatballavpurHUB_BAC  ONBOARDED
# 5   Siddhartha Sankar Kha  7596912010        UluberiaHUB_ULB  ONBOARDED
# 6          Taroni Mohitri  9647207740  JagatballavpurHUB_BAC  ONBOARDED
# 7            Gopal Mondal  8777058373        UluberiaHUB_ULB  ONBOARDED
# 8       Farida Begam Kazi  9903296247        UluberiaHUB_ULB  ONBOARDED
# 9            Sk Rahim Ali  9093786422  JagatballavpurHUB_BAC  ONBOARDED
# 10          Souvik Pachal  7699068074  JagatballavpurHUB_BAC  ONBOARDED
# 11       Raj Sundar Banka  8637391265  JagatballavpurHUB_BAC  ONBOARDED
# ...

# %%
print(type(D['OBDate']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
D.sample(3)
# Out:
#               NAME      Mobile               HUB NAME     STATUS  \
# 12     Anirban Das  8670335001  JagatballavpurHUB_BAC  ONBOARDED
# 2   Sourav Samanta  8420932177        UluberiaHUB_ULB  ONBOARDED
# 1       Bikram Das  6296875698  JagatballavpurHUB_BAC  ONBOARDED
#
#    Expected joining     OBDate  RSPS   MODEL                   Remarks
# 12     Join On 11th 2022-08-10   NaN  KIRANA       Trainning From 11th
# 2      Join On 10th 2022-08-05   NaN  KIRANA  Movement To Ghadiara HUB
# 1      Join On 09th 2022-08-05   NaN  KIRANA    NOT Interested To Join

# %%
D.head(5)
# Out:
#              NAME      Mobile               HUB NAME     STATUS  \
# 0     Raja Mondal  7363829439  JagatballavpurHUB_BAC  ONBOARDED
# 1      Bikram Das  6296875698  JagatballavpurHUB_BAC  ONBOARDED
# 2  Sourav Samanta  8420932177        UluberiaHUB_ULB  ONBOARDED
# 3  Raghunath Rong  9547917952        UluberiaHUB_ULB  ONBOARDED
# 4     Susanta Bag  7715956761  JagatballavpurHUB_BAC  ONBOARDED
#
#   Expected joining     OBDate  RSPS   MODEL                       Remarks
# 0     join on 12th 2022-08-04   NaN  KIRANA                  Join On 12th
# 1     Join On 09th 2022-08-05   NaN  KIRANA        NOT Interested To Join
# 2     Join On 10th 2022-08-05   NaN  KIRANA      Movement To Ghadiara HUB
# 3     join on 10th 2022-08-06   NaN  KIRANA  On Trainning / Action needed
# 4     Join On 09th 2022-08-06   NaN  KIRANA              Call No Response

# %%
D.tail(2)
# Out:
#                 NAME      Mobile               HUB NAME     STATUS  \
# 11  Raj Sundar Banka  8637391265  JagatballavpurHUB_BAC  ONBOARDED
# 12       Anirban Das  8670335001  JagatballavpurHUB_BAC  ONBOARDED
#
#    Expected joining     OBDate  RSPS   MODEL              Remarks
# 11     join on 11th 2022-08-09   NaN  KIRANA  Trainning From 11th
# 12     Join On 11th 2022-08-10   NaN  KIRANA  Trainning From 11th

# %%
ds1=pd.read_csv('empl.csv')
ds1
# Out:
#     SNo      Name   Age       City  Country   Salary
# 0     1       Tom  28.0    Toronto   Canada  20000.0
# 1     2       Lee  31.0    Edmonto   Canada   3900.0
# 2     3      Dave  34.0    Toronto   Canada   8000.0
# 3     4      Anik  26.0   HongKong     Asia  66672.0
# 4     5     kamal  30.0        NaN  America      NaN
# 5     6      Geet   NaN   HongKong     Asia  30007.0
# 6     7    Steven  43.0    BayArea  America   8300.0
# 7     8       Ram  38.0  Hyderabad     Asia  54666.0
# 8     9      hari  50.0    newyork  America  67666.0
# 9    11      yami   NaN    newyork  America   8888.0
# 10   12      Anik  26.0   HongKong     Asia  66672.0
# 11   13     kamal  30.0        NaN  America  34344.0
# 12   14      Geet  22.0   HongKong     Asia  30007.0
# 13   15    Steven  43.0        NaN  America   8300.0
# 14   16       Ram  38.0  Hyderabad     Asia  54666.0
# 15   17      hari   NaN    newyork  America  67666.0
# 16   18      yami  27.0    newyork  America   8888.0
# ...

# %%
ds1.drop([21,22],inplace=True,axis=0)

# %%
ds1
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0        NaN  America      NaN
# 5     6    Geet   NaN   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami   NaN    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0        NaN  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0        NaN  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari   NaN    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
ds1.describe()
# Out:
#              SNo        Age        Salary
# count  21.000000  18.000000     19.000000
# mean   11.571429  32.722222  33739.947368
# std     6.645084   7.258306  23151.188084
# min     1.000000  22.000000   3900.000000
# 25%     6.000000  27.250000   8888.000000
# 50%    12.000000  31.000000  33451.000000
# 75%    17.000000  37.000000  54666.000000
# max    22.000000  50.000000  67666.000000

# %%
ds1.describe(include='all')
# Out:
#               SNo Name        Age      City  Country        Salary
# count   21.000000   21  18.000000        18       21     19.000000
# unique        NaN   13        NaN         9        5           NaN
# top           NaN  Lee        NaN  HongKong  America           NaN
# freq          NaN    2        NaN         4        8           NaN
# mean    11.571429  NaN  32.722222       NaN      NaN  33739.947368
# std      6.645084  NaN   7.258306       NaN      NaN  23151.188084
# min      1.000000  NaN  22.000000       NaN      NaN   3900.000000
# 25%      6.000000  NaN  27.250000       NaN      NaN   8888.000000
# 50%     12.000000  NaN  31.000000       NaN      NaN  33451.000000
# 75%     17.000000  NaN  37.000000       NaN      NaN  54666.000000
# max     22.000000  NaN  50.000000       NaN      NaN  67666.000000

# %%
ds2=pd.read_csv('empl.csv',index_col=['SNo'])
ds2
# Out:
#          Name   Age       City  Country   Salary
# SNo
# 1         Tom  28.0    Toronto   Canada  20000.0
# 2         Lee  31.0    Edmonto   Canada   3900.0
# 3        Dave  34.0    Toronto   Canada   8000.0
# 4        Anik  26.0   HongKong     Asia  66672.0
# 5       kamal  30.0        NaN  America      NaN
# 6        Geet   NaN   HongKong     Asia  30007.0
# 7      Steven  43.0    BayArea  America   8300.0
# 8         Ram  38.0  Hyderabad     Asia  54666.0
# 9        hari  50.0    newyork  America  67666.0
# 11       yami   NaN    newyork  America   8888.0
# 12       Anik  26.0   HongKong     Asia  66672.0
# 13      kamal  30.0        NaN  America  34344.0
# 14       Geet  22.0   HongKong     Asia  30007.0
# 15     Steven  43.0        NaN  America   8300.0
# 16        Ram  38.0  Hyderabad     Asia  54666.0
# 17       hari   NaN    newyork  America  67666.0
# 18       yami  27.0    newyork  America   8888.0
# 19        Lee  31.0    Edmonto   Canada      NaN
# ...

# %%
ds2.count()                               #gives No of Columns values
# Out:
# Name       23
# Age        19
# City       20
# Country    23
# Salary     20
# dtype: int64

# %%
ds2['Age'].unique()
# Out:
# array([28., 31., 34., 26., 30., nan, 43., 38., 50., 22., 27., 32.])

# %%
ds2['Country'].unique()                  #gives unique values
# Out:
# array(['Canada', 'Asia', 'America', 'Africa', 'Europe', 'India'],
#       dtype=object)

# %%
ds2['Country'].nunique()                 #gives No of Unique values
# Out:
# 6

# %%
print(ds2['Name'].describe())
# Out:
# count      23
# unique     15
# top       Lee
# freq        2
# Name: Name, dtype: object

# %%
print(ds2['Country'].describe())
# Out:
# count          23
# unique          6
# top       America
# freq            8
# Name: Country, dtype: object

# %%
ds2.describe()
# Out:
#              Age        Salary
# count  19.000000     20.000000
# mean   32.421053  33302.950000
# std     7.174924  22618.300137
# min    22.000000   3900.000000
# 25%    27.000000   8888.000000
# 50%    31.000000  31729.000000
# 75%    36.000000  54666.000000
# max    50.000000  67666.000000

# %%
ds2.describe(include='all')
# Out:
#        Name        Age      City  Country        Salary
# count    23  19.000000        20       23     20.000000
# unique   15        NaN        11        6           NaN
# top     Lee        NaN  HongKong  America           NaN
# freq      2        NaN         4        8           NaN
# mean    NaN  32.421053       NaN      NaN  33302.950000
# std     NaN   7.174924       NaN      NaN  22618.300137
# min     NaN  22.000000       NaN      NaN   3900.000000
# 25%     NaN  27.000000       NaN      NaN   8888.000000
# 50%     NaN  31.000000       NaN      NaN  31729.000000
# 75%     NaN  36.000000       NaN      NaN  54666.000000
# max     NaN  50.000000       NaN      NaN  67666.000000

# %%
ds2['Salary'].max()
# Out:
# 67666.0

# %%
ds2['Salary'].plot.bar()
# Out:
# <AxesSubplot:xlabel='SNo'>

# %%
ds2['Age'].plot.barh()
# Out:
# <AxesSubplot:ylabel='SNo'>

# %%
print(ds2.dtypes)
# Out:
# Name        object
# Age        float64
# City        object
# Country     object
# Salary     float64
# dtype: object

# %%
print(type(ds2['Salary'][13]))
# Out:
# <class 'numpy.float64'>

# %%
ds2.head(4)
# Out:
#      Name   Age      City Country   Salary
# SNo
# 1     Tom  28.0   Toronto  Canada  20000.0
# 2     Lee  31.0   Edmonto  Canada   3900.0
# 3    Dave  34.0   Toronto  Canada   8000.0
# 4    Anik  26.0  HongKong    Asia  66672.0

# %%
ds2.tail(5)
# Out:
#          Name   Age     City Country   Salary
# SNo
# 20     Andrew  34.0    Congo  Africa  34432.0
# 21      soham  32.0   Angola  Africa  34534.0
# 22       Grig  26.0  Finland  Europe  33451.0
# 23      Kiara  27.0   London  Europe      NaN
# 24   Shreyasi   NaN  Kolkata   India  25000.0

# %%
ds2['Age'].min()
# Out:
# 22.0

# %%
ds2['Salary'].min()
# Out:
# 3900.0

# %%
ds2['Age'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
ds2['Salary'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
ds2['Salary'].plot()
# Out:
# <AxesSubplot:xlabel='SNo'>

# %%
ds2['Age'].plot()
# Out:
# <AxesSubplot:xlabel='SNo'>

# %%
data1=pd.read_csv('exammarks.csv',index_col=['Name'],parse_dates=['DOB'])
data1
# Out:
#          Gender        DOB  Maths  Physics  Chemistry  English  Biology  \
# Name
# John          M 1988-05-04     55       45         56       87       21
# Suresh        M 1987-04-05     75       96         78       64       90
# Ramesh        M 1989-05-25     25       54         89       76       95
# Jessica       F 1990-12-08     78       96         86       63       54
# Jennifer      F 1989-02-09     58       96         78       46       96
# Annu          F 1988-05-04     45       87         52       89       55
# pooja         F 1987-04-05     55       64         61       58       75
# Ritesh        M 1989-05-25     54       76         87       56       25
# Farha         F 1990-12-08     55       63         89       75       78
# Mukesh        M 1989-02-09     96       46         77       83       58
#
#           Economics  History  Civics
# Name
# John             52       89      65
# Suresh           61       58       2
# Ramesh           87       56      74
# ...

# %%
Df1=pd.DataFrame(data1)
Df1
# Out:
#          Gender        DOB  Maths  Physics  Chemistry  English  Biology  \
# Name
# John          M 1988-05-04     55       45         56       87       21
# Suresh        M 1987-04-05     75       96         78       64       90
# Ramesh        M 1989-05-25     25       54         89       76       95
# Jessica       F 1990-12-08     78       96         86       63       54
# Jennifer      F 1989-02-09     58       96         78       46       96
# Annu          F 1988-05-04     45       87         52       89       55
# pooja         F 1987-04-05     55       64         61       58       75
# Ritesh        M 1989-05-25     54       76         87       56       25
# Farha         F 1990-12-08     55       63         89       75       78
# Mukesh        M 1989-02-09     96       46         77       83       58
#
#           Economics  History  Civics
# Name
# John             52       89      65
# Suresh           61       58       2
# Ramesh           87       56      74
# ...

# %%
print(type(Df1['DOB'][5]))
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
print(data1.dtypes)
# Out:
# Gender               object
# DOB          datetime64[ns]
# Maths                 int64
# Physics               int64
# Chemistry             int64
# English               int64
# Biology               int64
# Economics             int64
# History               int64
# Civics                int64
# dtype: object

# %%
Df1.loc['Ramesh':'Annu','Maths':'English']
# Out:
#           Maths  Physics  Chemistry  English
# Name
# Ramesh       25       54         89       76
# Jessica      78       96         86       63
# Jennifer     58       96         78       46
# Annu         45       87         52       89

# %%
Df1.loc['pooja':'Farha','Economics':'Civics']
# Out:
#         Economics  History  Civics
# Name
# pooja          58       64      61
# Ritesh         56       76      87
# Farha          75       63      89

# %%
Df1.iloc[3:8,:4]
# Out:
#          Gender        DOB  Maths  Physics
# Name
# Jessica       F 1990-12-08     78       96
# Jennifer      F 1989-02-09     58       96
# Annu          F 1988-05-04     45       87
# pooja         F 1987-04-05     55       64
# Ritesh        M 1989-05-25     54       76

# %%
Df1.iloc[-3:,-3]
# Out:
# Name
# Ritesh    56
# Farha     75
# Mukesh    83
# Name: Economics, dtype: int64

# %%
Df1.count()
# Out:
# Gender       10
# DOB          10
# Maths        10
# Physics      10
# Chemistry    10
# English      10
# Biology      10
# Economics    10
# History      10
# Civics       10
# dtype: int64

# %%
Df1['Maths'].count()
# Out:
# 10

# %%
print(Df1['Maths'].describe())
# Out:
# count    10.000000
# mean     59.600000
# std      19.460501
# min      25.000000
# 25%      54.250000
# 50%      55.000000
# 75%      70.750000
# max      96.000000
# Name: Maths, dtype: float64

# %%
print(Df1['Gender'].describe())
# Out:
# count     10
# unique     2
# top        M
# freq       5
# Name: Gender, dtype: object

# %%
print(Df1['History'].describe())
# Out:
# count    10.000000
# mean     69.700000
# std      14.453373
# min      46.000000
# 25%      59.250000
# 50%      69.500000
# 75%      81.250000
# max      89.000000
# Name: History, dtype: float64

# %%
Df1.describe()
# Out:
#            Maths    Physics  Chemistry    English    Biology  Economics  \
# count  10.000000  10.000000  10.000000  10.000000  10.000000  10.000000
# mean   59.600000  72.300000  75.300000  69.700000  64.700000  72.700000
# std    19.460501  20.661559  14.000397  14.453373  26.998148  14.629119
# min    25.000000  45.000000  52.000000  46.000000  21.000000  52.000000
# 25%    54.250000  56.250000  65.000000  59.250000  54.250000  58.750000
# 50%    55.000000  70.000000  78.000000  69.500000  66.500000  76.000000
# 75%    70.750000  93.750000  86.750000  81.250000  87.000000  86.000000
# max    96.000000  96.000000  89.000000  89.000000  96.000000  89.000000
#
#          History   Civics
# count  10.000000  10.0000
# mean   69.700000  60.5000
# std    14.453373  25.3432
# min    46.000000   2.0000
# 25%    59.250000  52.2500
# 50%    69.500000  63.0000
# 75%    81.250000  76.2500
# max    89.000000  89.0000

# %%
Df1.describe(include='all')
# Out:
# C:\Users\SHREYA~1\AppData\Local\Temp/ipykernel_14324/143638146.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   Df1.describe(include='all')
#        Gender                  DOB      Maths    Physics  Chemistry  \
# count      10                   10  10.000000  10.000000  10.000000
# unique      2                    5        NaN        NaN        NaN
# top         M  1988-05-04 00:00:00        NaN        NaN        NaN
# freq        5                    2        NaN        NaN        NaN
# first     NaN  1987-04-05 00:00:00        NaN        NaN        NaN
# last      NaN  1990-12-08 00:00:00        NaN        NaN        NaN
# mean      NaN                  NaN  59.600000  72.300000  75.300000
# std       NaN                  NaN  19.460501  20.661559  14.000397
# ...

# %%
Df2=Df1.drop(['Farha','Mukesh'],axis=0)   #for a drop an entire row/Multiple row is axis=0
Df2
# Out:
#          Gender        DOB  Maths  Physics  Chemistry  English  Biology  \
# Name
# John          M 1988-05-04     55       45         56       87       21
# Suresh        M 1987-04-05     75       96         78       64       90
# Ramesh        M 1989-05-25     25       54         89       76       95
# Jessica       F 1990-12-08     78       96         86       63       54
# Jennifer      F 1989-02-09     58       96         78       46       96
# Annu          F 1988-05-04     45       87         52       89       55
# pooja         F 1987-04-05     55       64         61       58       75
# Ritesh        M 1989-05-25     54       76         87       56       25
#
#           Economics  History  Civics
# Name
# John             52       89      65
# Suresh           61       58       2
# Ramesh           87       56      74
# Jessica          89       75      45
# Jennifer         77       83      53
# Annu             89       87      52
# pooja            58       64      61
# ...

# %%
Df3=Df2.drop(['Civics'],axis=1)   #for drop an entire column/Multiple column is axis=1
Df3
# Out:
#          Gender        DOB  Maths  Physics  Chemistry  English  Biology  \
# Name
# John          M 1988-05-04     55       45         56       87       21
# Suresh        M 1987-04-05     75       96         78       64       90
# Ramesh        M 1989-05-25     25       54         89       76       95
# Jessica       F 1990-12-08     78       96         86       63       54
# Jennifer      F 1989-02-09     58       96         78       46       96
# Annu          F 1988-05-04     45       87         52       89       55
# pooja         F 1987-04-05     55       64         61       58       75
# Ritesh        M 1989-05-25     54       76         87       56       25
#
#           Economics  History
# Name
# John             52       89
# Suresh           61       58
# Ramesh           87       56
# Jessica          89       75
# Jennifer         77       83
# Annu             89       87
# pooja            58       64
# Ritesh           56       76

# %%
Df3.drop(['History'],inplace=True,axis=1)

# %%
Df3
# Out:
#          Gender        DOB  Maths  Physics  Chemistry  Biology  Economics
# Name
# John          M 1988-05-04     55       45         56       21         52
# Suresh        M 1987-04-05     75       96         78       90         61
# Ramesh        M 1989-05-25     25       54         89       95         87
# Jessica       F 1990-12-08     78       96         86       54         89
# Jennifer      F 1989-02-09     58       96         78       96         77
# Annu          F 1988-05-04     45       87         52       55         89
# pooja         F 1987-04-05     55       64         61       75         58
# Ritesh        M 1989-05-25     54       76         87       25         56
